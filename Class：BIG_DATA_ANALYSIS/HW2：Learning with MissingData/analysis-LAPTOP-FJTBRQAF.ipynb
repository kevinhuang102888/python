# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
data1=pd.read_csv(".\\hw2_data\\data1\\train.csv",header=None)
data2=pd.read_csv(".\\hw2_data\\data2\\train.csv",header=None)
data3=pd.read_csv(".\\hw2_data\\data3\\train.csv",header=None)
data4=pd.read_csv(".\\hw2_data\\data4\\train.csv",header=None)
data5=pd.read_csv(".\\hw2_data\\data5\\train.csv",header=None)
data6=pd.read_csv(".\\hw2_data\\data6\\train.csv",header=None)
data7=pd.read_csv(".\\hw2_data\\data7\\train.csv",header=None)

# %% [markdown]
# # 相關性分析

# %%
import seaborn as sns
sns.heatmap(data1.corr(), vmax=1, square=True, cmap="Blues")
plt.title("Data 1", fontsize =20)
plt.show()

# %%
sns.heatmap(data2.corr(), vmax=1, square=True, cmap="Blues")
plt.title("Data 2", fontsize =20)
plt.show()

# %%
sns.heatmap(data3.corr(), vmax=1, square=True, cmap="Blues")
plt.title("Data 3", fontsize =20)
plt.show()

# %%
sns.heatmap(data4.corr(), vmax=1, square=True, cmap="Blues")
plt.title("Data 4", fontsize =20)
plt.show()

# %%
sns.heatmap(data5.corr(), vmax=1, square=True, cmap="Blues")
plt.title("Data 5", fontsize =20)
plt.show()

# %%
sns.heatmap(data6.corr(), vmax=1, square=True, cmap="Blues")
plt.title("Data 6", fontsize =20)
plt.show()

# %%
sns.heatmap(data7.corr(), vmax=1, square=True, cmap="Blues")
plt.title("Data 7", fontsize =20)
plt.show()

# %% [markdown]
# # 預測資料分析

# %%
from pylab import mpl
plt.rcParams['font.sans-serif'] = ['Microsoft JhengHei']

# %%
plt.hist(data1.iloc[:,-1],bins=25,color="#A2D2FF")
plt.title("Data 1 目標值分布", fontsize =20)
plt.show()

# %%
plt.hist(data2.iloc[:,-1],bins=25,color="#A2D2FF")
plt.title("Data 2 目標值分布", fontsize =20)
plt.show()

# %%
plt.hist(data3.iloc[:,-1],bins=25,color="#A2D2FF")
plt.title("Data 3 目標值分布", fontsize =20)
plt.show()

# %%
plt.hist(data4.iloc[:,-1],bins=25,color="#A2D2FF")
plt.title("Data 4 目標值分布", fontsize =20)
plt.show()

# %%
plt.hist(data5.iloc[:,-1],bins=25,color="#A2D2FF")
plt.title("Data 5 目標值分布", fontsize =20)
plt.show()

# %%
plt.hist(data6.iloc[:,-1],bins=25,color="#A2D2FF")
plt.title("Data 6 目標值分布", fontsize =20)
plt.show()

# %%
plt.hist(data7.iloc[:,-1],bins=25,color="#A2D2FF")
plt.title("Data 7 目標值分布", fontsize =20)
plt.show()

# %% [markdown]
# # 遺失值分析

# %%
import missingno as msno
msno.matrix(data1)
plt.title("Data 1 遺失值分布", fontsize =40)
plt.show()

# %%
msno.matrix(data2)
plt.title("Data 2 遺失值分布", fontsize =40)
plt.show()

# %%
msno.matrix(data3)
plt.title("Data 3 遺失值分布", fontsize =40)
plt.show()

# %%
msno.matrix(data4)
plt.title("Data 4 遺失值分布", fontsize =40)
plt.show()

# %%
msno.matrix(data5)
plt.title("Data 5 遺失值分布", fontsize =40)
plt.show()

# %%
msno.matrix(data6)
plt.title("Data 6 遺失值分布", fontsize =40)
plt.show()

# %%
msno.matrix(data7)
plt.title("Data 7 遺失值分布", fontsize =40)
plt.show()

# %%
msno.heatmap(data1)
plt.title("Data 1 遺失值兩兩相關", fontsize =30)
plt.show()

# %%
msno.heatmap(data2)
plt.title("Data 2 遺失值兩兩相關", fontsize =30)
plt.show()

# %%
msno.heatmap(data3)
plt.title("Data 3 遺失值兩兩相關", fontsize =30)
plt.show()

# %%
msno.heatmap(data4)
plt.title("Data 4 遺失值兩兩相關", fontsize =30)
plt.show()

# %%
msno.heatmap(data5)
plt.title("Data 5 遺失值兩兩相關", fontsize =30)
plt.show()

# %%
msno.heatmap(data6)
plt.title("Data 6 遺失值兩兩相關", fontsize =30)
plt.show()

# %%
msno.heatmap(data7)
plt.title("Data 7 遺失值兩兩相關", fontsize =30)
plt.show()

# %%
msno.dendrogram(data1)
plt.title("Data 1 遺失值相關分群", fontsize =40, y=1.08,color="#3D56B2")
# Out:
# Text(0.5, 1.08, 'Data 1 遺失值相關分群')

# %%
msno.dendrogram(data2)
plt.title("Data 2 遺失值相關分群", fontsize =40, y=1.08,color="#3D56B2")
# Out:
# Text(0.5, 1.08, 'Data 2 遺失值相關分群')

# %%
msno.dendrogram(data2)
plt.title("Data 3 遺失值相關分群", fontsize =40, y=1.08,color="#3D56B2")
# Out:
# Text(0.5, 1.08, 'Data 3 遺失值相關分群')

# %%
msno.dendrogram(data4)
plt.title("Data 4 遺失值相關分群", fontsize =40, y=1.08,color="#3D56B2")
# Out:
# Text(0.5, 1.08, 'Data 4 遺失值相關分群')

# %%
msno.dendrogram(data5)
plt.title("Data 5 遺失值相關分群", fontsize =40, y=1.08,color="#3D56B2")
# Out:
# Text(0.5, 1.08, 'Data 5 遺失值相關分群')

# %%
msno.dendrogram(data6)
plt.title("Data 6 遺失值相關分群", fontsize =40, y=1.08,color="#3D56B2")
# Out:
# Text(0.5, 1.08, 'Data 6 遺失值相關分群')

# %%
msno.dendrogram(data7)
plt.title("Data 7 遺失值相關分群", fontsize =40, y=1.08,color="#3D56B2")
# Out:
# Text(0.5, 1.08, 'Data 7 遺失值相關分群')
